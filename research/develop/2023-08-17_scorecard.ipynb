# %%
# Load packages and libraries
import pandas as pd
import numpy as np
import scorecardpy as sc
import pickle

# %%
woe = pd.read_csv("../../data/woe_data.csv")
coefs = pd.read_csv("../../data/scorecard_coefs.csv")

# %%
woe.head()
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines       age  \
# 0                 1                             -0.923599 -0.299612
# 1                 0                             -0.923599 -0.299612
# 2                 0                             -0.923599 -0.299612
# 3                 0                              0.930297 -0.549580
# 4                 0                             -0.923599  0.087465
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                             -1.616726  -0.574709       0.120450
# 1                              0.257826   0.144841      -0.274868
# 2                              0.257826   0.144841      -0.274868
# 3                              0.257826   0.144841      -0.274868
# 4                              0.257826   0.144841       0.460433
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                         0.035635                 0.176674
# 1                        -0.004249                 0.176674
# 2                        -0.004249                 0.176674
# 3                        -0.004249                 0.176674
# 4                        -0.004249                 0.176674
#
#    NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 0                     -0.592980                              0.288208
# 1                     -0.235970                              0.288208
# 2                     -0.235970                              0.288208
# 3                     -0.235970                              0.288208
# 4                      0.256641                              0.288208
#
#    NumberOfDependents  Qualified
# 0            0.031633          0
# 1            0.031633          1
# 2            0.031633          1
# 3            0.031633          1
# 4            0.031633          1

# %%
coefs
# Out:
#                                variable  coefficient
# 0  RevolvingUtilizationOfUnsecuredLines     0.687558
# 1                                   age     0.462295
# 2  NumberOfTime30-59DaysPastDueNotWorse     0.510296
# 3                             DebtRatio     0.839662
# 4                         MonthlyIncome     0.192723
# 5               NumberOfTimes90DaysLate     0.509898
# 6          NumberRealEstateLoansOrLines     0.716267
# 7  NumberOfTime60-89DaysPastDueNotWorse     0.500170
# 8                    NumberOfDependents     0.439731
# 9                             Intercept     2.603919

# %%
with open('../../data/logreg.pkl', 'rb') as f:
    lr = pickle.load(f) # deserialize using load()
    print(type(lr))
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>

# %%
pdo=20
factor=pdo/np.log(2)
offset = 600 - (factor*np.log(50))
print('Factor:', round(factor,2),'| Offset:', round(offset,2))
# Out:
# Factor: 28.85 | Offset: 487.12

# %% [markdown]
# ## Calculate Scores for each bin
#
# $Score_i= (βi × WoE_i + α/n) × Factor + Offset/n$
#
# Where:
# * βi — logistic regression coefficient for the variable Xi
# * α — logistic regression intercept
# * WoE — Weight of Evidence value for variable Xi
# * n — number of independent variable Xi in the model
# * Factor, Offset — known as scaling parameter, where
#
# Factor = pdo/ln(2)
#
# Offset = Target Score — (Factor × ln(Target Odds))

# %%
iv_df = pd.read_csv("../../data/report_iv.csv")
iv_df.drop(columns=['Unnamed: 0'], inplace=True)
iv_df.rename(columns={'IV':'total_iv'}, inplace=True)
iv_df
# Out:
#                                Variable  total_iv
# 0  RevolvingUtilizationOfUnsecuredLines  0.980756
# 1                                   age  0.219824
# 2  NumberOfTime30-59DaysPastDueNotWorse  0.486538
# 3                             DebtRatio  0.061371
# 4                         MonthlyIncome  0.063546
# 5       NumberOfOpenCreditLinesAndLoans  0.000375
# 6               NumberOfTimes90DaysLate  0.485778
# 7          NumberRealEstateLoansOrLines  0.060411
# 8  NumberOfTime60-89DaysPastDueNotWorse  0.600050
# 9                    NumberOfDependents  0.017337

# %%
woe_bins = pd.read_csv('../../data/report_woe.csv')
woe_bins.drop(columns=['Unnamed: 0'], inplace=True)
woe_bins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Variable         39 non-null     object
#  1   QuantileRange    37 non-null     object
#  2   EventsCount      39 non-null     int64
#  3   EventsSum        39 non-null     int64
#  4   % of Qualified   39 non-null     float64
#  5   DelinquentCount  39 non-null     int64
#  6   % of Delinquent  39 non-null     float64
#  7   WoE              39 non-null     float64
#  8   IV               39 non-null     float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 2.9+ KB

# %%
woe_bins = woe_bins.merge(iv_df, left_on='Variable', right_on='Variable', how='left')

# %%
woe_bins.fillna('None', inplace=True)

# %%
woe_bins
# Out:
#                                 Variable     QuantileRange  EventsCount  \
# 0   RevolvingUtilizationOfUnsecuredLines     (-100.0, 0.5]       108712
# 1   RevolvingUtilizationOfUnsecuredLines        (0.5, 1.0]        37967
# 2   RevolvingUtilizationOfUnsecuredLines        (1.0, 1.5]         2721
# 3   RevolvingUtilizationOfUnsecuredLines    (1.5, 60000.0]          600
# 4                                    age        (-100, 18]            1
# 5                                    age          (18, 26]         4220
# 6                                    age          (26, 35]        17265
# 7                                    age          (35, 45]        29819
# 8                                    age          (45, 65]        70096
# 9                                    age         (65, 120]        28599
# 10  NumberOfTime30-59DaysPastDueNotWorse     (-0.098, 1.0]       142051
# 11  NumberOfTime30-59DaysPastDueNotWorse        (1.0, 2.0]         4598
# 12  NumberOfTime30-59DaysPastDueNotWorse      (2.0, 100.0]         3351
# 13                             DebtRatio  (-100.0, 0.3125]        65035
# 14                             DebtRatio   (0.3125, 0.625]        38561
# 15                             DebtRatio      (0.625, 2.5]        15750
# 16                             DebtRatio   (2.5, 330000.0]        30654
# 17                         MonthlyIncome      (-100, 5000]        55859
# 18                         MonthlyIncome  (10000, 1000000]        18315
# 19                         MonthlyIncome     (5000, 10000]        46091
# 20                         MonthlyIncome              None        29735
# 21       NumberOfOpenCreditLinesAndLoans    (-100.0, 11.6]       115311
# 22       NumberOfOpenCreditLinesAndLoans      (11.6, 17.4]        26233
# 23       NumberOfOpenCreditLinesAndLoans      (17.4, 58.0]         8456
# 24               NumberOfTimes90DaysLate     (-100.0, 1.0]       146905
# 25               NumberOfTimes90DaysLate        (1.5, 5.0]         2644
# 26               NumberOfTimes90DaysLate      (10.0, 98.0]          285
# 27               NumberOfTimes90DaysLate       (5.0, 10.0]          166
# 28          NumberRealEstateLoansOrLines     (-100.0, 0.5]        56188
# 29          NumberRealEstateLoansOrLines        (0.5, 1.0]        52338
# 30          NumberRealEstateLoansOrLines        (1.0, 3.0]        37822
# 31          NumberRealEstateLoansOrLines       (3.0, 54.0]         3652
# 32  NumberOfTime60-89DaysPastDueNotWorse         (-100, 0]       142396
# 33  NumberOfTime60-89DaysPastDueNotWorse            (0, 1]         5731
# 34  NumberOfTime60-89DaysPastDueNotWorse            (1, 2]         1118
# 35  NumberOfTime60-89DaysPastDueNotWorse          (2, 100]          755
# 36                    NumberOfDependents         (-100, 2]       132740
# 37                    NumberOfDependents           (2, 20]        13336
# 38                    NumberOfDependents              None         3924
#
#     EventsSum  % of Qualified  DelinquentCount  % of Delinquent       WoE  \
# 0        2987        0.297925           105725         0.755319  0.930297
# 1        5802        0.578695            32165         0.229793 -0.923599
# 2        1081        0.107820             1640         0.011716 -2.219465
# 3         156        0.015560              444         0.003172 -1.590306
# 4           0        0.000050                1         0.000007 -1.943128
# 5         485        0.048374             3735         0.026684 -0.594921
# 6        1906        0.190106            15359         0.109728 -0.549580
# 7        2628        0.262118            27191         0.194258 -0.299612
# 8        4317        0.430580            65779         0.469937  0.087465
# 9         690        0.068821            27909         0.199387  1.063738
# 10       7450        0.743068           134601         0.961614  0.257826
# 11       1219        0.121584             3379         0.024140 -1.616726
# 12       1357        0.135348             1994         0.014246 -2.251409
# 13       3795        0.378516            61240         0.437510  0.144841
# 14       2745        0.273788            35816         0.255876 -0.067661
# 15       1778        0.177339            13972         0.099819 -0.574709
# 16       1708        0.170357            28946         0.206796  0.193834
# 17       4813        0.480052            51046         0.364682 -0.274868
# 18        792        0.078995            17523         0.125188  0.460433
# 19       2752        0.274486            43339         0.309622  0.120450
# 20       1669        0.166467            28066         0.200509  0.186059
# 21       7738        0.771793           107573         0.768521 -0.004249
# 22       1696        0.169160            24537         0.175297  0.035635
# 23        592        0.059046             7864         0.056182 -0.049731
# 24       8319        0.829743           138586         0.990084  0.176674
# 25       1439        0.143527             1205         0.008609 -2.813744
# 26        155        0.015460              130         0.000929 -2.812166
# 27        113        0.011271               53         0.000379 -3.393371
# 28       4672        0.465988            51516         0.368040 -0.235970
# 29       2748        0.274087            49590         0.354280  0.256641
# 30       2187        0.218133            35635         0.254583  0.154523
# 31        419        0.041791             3233         0.023097 -0.592980
# 32       7256        0.723718           135140         0.965465  0.288208
# 33       1777        0.177239             3954         0.028248 -1.836474
# 34        561        0.055955              557         0.003979 -2.643431
# 35        432        0.043088              323         0.002308 -2.927048
# 36       8614        0.859166           124126         0.886779  0.031633
# 37       1233        0.122980            12103         0.086466 -0.352272
# 38        179        0.017854             3745         0.026755  0.404516
#
#           IV  total_iv
# 0   0.425512  0.980756
# 1   0.322246  0.980756
# 2   0.213298  0.980756
# 3   0.019700  0.980756
# 4   0.000083  0.219824
# 5   0.012904  0.219824
# 6   0.044174  0.219824
# 7   0.020332  0.219824
# 8   0.003442  0.219824
# 9   0.138888  0.219824
# 10  0.056347  0.486538
# 11  0.157540  0.486538
# 12  0.272651  0.486538
# 13  0.008545  0.061371
# 14  0.001212  0.061371
# 15  0.044552  0.061371
# 16  0.007063  0.061371
# 17  0.031712  0.063546
# 18  0.021269  0.063546
# 19  0.004232  0.063546
# 20  0.006334  0.063546
# 21  0.000014  0.000375
# 22  0.000219  0.000375
# 23  0.000142  0.000375
# 24  0.028328  0.485778
# 25  0.379625  0.485778
# 26  0.040864  0.485778
# 27  0.036961  0.485778
# 28  0.023113  0.060411
# 29  0.020581  0.060411
# 30  0.005632  0.060411
# 31  0.011085  0.060411
# 32  0.069673  0.600050
# 33  0.273618  0.600050
# 34  0.137393  0.600050
# 35  0.119366  0.600050
# 36  0.000873  0.017337
# 37  0.012863  0.017337
# 38  0.003601  0.017337

# %%
breaks_list = []

for variable in woe.columns:
    for item in woe_bins[(woe_bins['Variable'] == variable) & woe_bins['QuantileRange']].iterrows():
            if type(item[1]['QuantileRange']) == str:
                breaks_list.append(np.nan)
            else:
                range_bounds = item[1]['QuantileRange'][1:-1].split(', ')
                range_bounds = [float(num) for num in range_bounds]
                breaks_list.append(range_bounds[1])
            print(item[1]['QuantileRange'])

# len(breaks_list)
# Out:
# (-100.0, 0.5]
# (0.5, 1.0]
# (1.0, 1.5]
# (1.5, 60000.0]
# (-100, 18]
# (18, 26]
# (26, 35]
# (35, 45]
# (45, 65]
# (65, 120]
# (-0.098, 1.0]
# (1.0, 2.0]
# (2.0, 100.0]
# (-100.0, 0.3125]
# (0.3125, 0.625]
# (0.625, 2.5]
# (2.5, 330000.0]
# (-100, 5000]
# (10000, 1000000]
# (5000, 10000]
# None
# (-100.0, 11.6]
# (11.6, 17.4]
# (17.4, 58.0]
# (-100.0, 1.0]
# (1.5, 5.0]
# (10.0, 98.0]
# (5.0, 10.0]
# (-100.0, 0.5]
# (0.5, 1.0]
# (1.0, 3.0]
# (3.0, 54.0]
# (-100, 0]
# (0, 1]
# (1, 2]
# (2, 100]
# (-100, 2]
# (2, 20]
# None

# %%
woe_bins['breaks'] = breaks_list

# %%
new_woe_column_names = {
    'Variable':"variable",
    'QuantileRange':'bin',
    '% of Qualified':'count_distr',
    'EventsCount':'good',
    'DelinquentCount':'bad',
    '% of Delinquent':'badprob',
    'WoE':'woe',
    'IV':'bin_iv'}
    
woe_bins.rename(columns=new_woe_column_names, inplace=True)

# %%
woe_bins['count'] = woe_bins['good'] + woe_bins['bad']

# %%
woe_bins['is_special_values'] = False

# %%
woe_bins.head()
# Out:
#                                variable             bin    good  EventsSum  \
# 0  RevolvingUtilizationOfUnsecuredLines   (-100.0, 0.5]  108712       2987
# 1  RevolvingUtilizationOfUnsecuredLines      (0.5, 1.0]   37967       5802
# 2  RevolvingUtilizationOfUnsecuredLines      (1.0, 1.5]    2721       1081
# 3  RevolvingUtilizationOfUnsecuredLines  (1.5, 60000.0]     600        156
# 4                                   age      (-100, 18]       1          0
#
#    count_distr     bad   badprob       woe    bin_iv  total_iv  breaks  \
# 0     0.297925  105725  0.755319  0.930297  0.425512  0.980756     NaN
# 1     0.578695   32165  0.229793 -0.923599  0.322246  0.980756     NaN
# 2     0.107820    1640  0.011716 -2.219465  0.213298  0.980756     NaN
# 3     0.015560     444  0.003172 -1.590306  0.019700  0.980756     NaN
# 4     0.000050       1  0.000007 -1.943128  0.000083  0.219824     NaN
#
#     count  is_special_values
# 0  214437              False
# 1   70132              False
# 2    4361              False
# 3    1044              False
# 4       2              False

# %%
train = pd.read_csv("../../data/cs-training.csv")

# %%
bins = sc.woebin(train, y="SeriousDlqin2yrs")
# Out:
# [INFO] creating woe binning ...

# %%
breaks_adj = {
    'NumberOfDependents': [2, 20],
    'RevolvingUtilizationOfUnsecuredLines': [0.5, 1, 1.5],
    'age': [18, 26, 35, 45, 65],
    'NumberOfTime30-59DaysPastDueNotWorse': [1,2],
    'DebtRatio': [.3125, .625, 2.5,],
    'MonthlyIncome': [5000, 10_000],
    'NumberOfOpenCreditLinesAndLoans': [11.6, 17.4],
    'NumberOfTimes90DaysLate': [1, 1.5, 5, 10],
    'NumberRealEstateLoansOrLines': [0.5, 1, 3],
    'NumberOfTime60-89DaysPastDueNotWorse': [0, 1, 2]
}

# %%
# binning adjustment
bins_adj = sc.woebin(train, y="SeriousDlqin2yrs", breaks_list=breaks_adj)
# Out:
# [INFO] creating woe binning ...

# %%
# Drop columns that were not used in the logreg model
x_woe = woe.drop(columns=['SeriousDlqin2yrs', 'NumberOfOpenCreditLinesAndLoans', 'Qualified'])
xcolumns = x_woe.columns

# %%
bins_adj
# Out:
# {'NumberOfTime30-59DaysPastDueNotWorse':                                variable         bin   count  count_distr  \
#  0  NumberOfTime30-59DaysPastDueNotWorse  [-inf,1.0)  126018     0.840120
#  1  NumberOfTime30-59DaysPastDueNotWorse   [1.0,2.0)   16033     0.106887
#  2  NumberOfTime30-59DaysPastDueNotWorse   [2.0,inf)    7949     0.052993
#
#       good   bad   badprob       woe    bin_iv  total_iv breaks  \
#  0  120977  5041  0.040002 -0.541721  0.195826  0.740481    1.0
#  1   13624  2409  0.150253  0.903654  0.129171  0.740481    2.0
#  2    5373  2576  0.324066  1.901126  0.415484  0.740481    inf
#
#     is_special_values
#  0              False
#  1              False
#  2              False  ,
#  'DebtRatio':     variable             bin  count  count_distr   good   bad   badprob  \
#  0  DebtRatio   [-inf,0.3125)  65035     0.433567  61240  3795  0.058353
#  1  DebtRatio  [0.3125,0.625)  38561     0.257073  35816  2745  0.071186
#  2  DebtRatio     [0.625,2.5)  15748     0.104987  13970  1778  0.112903
#  3  DebtRatio       [2.5,inf)  30656     0.204373  28948  1708  0.055715
#
#          woe    bin_iv  total_iv  breaks  is_special_values
#  0 -0.144841  0.008545  0.061396  0.3125              False
#  1  0.067661  0.001212  0.061396   0.625              False
#  2  0.574852  0.044571  0.061396     2.5              False
#  3 -0.193903  0.007068  0.061396     inf              False  ,
#  'RevolvingUtilizationOfUnsecuredLines':                                variable         bin   count  count_distr  \
#  0  RevolvingUtilizationOfUnsecuredLines  [-inf,0.5)  108712     0.724747
#  1  RevolvingUtilizationOfUnsecuredLines   [0.5,1.0)   37950     0.253000
#  2  RevolvingUtilizationOfUnsecuredLines   [1.0,1.5)    2738     0.018253
#  3  RevolvingUtilizationOfUnsecuredLines   [1.5,inf)     600     0.004000
#
#       good   bad   badprob       woe    bin_iv  total_iv breaks  \
#  0  105725  2987  0.027476 -0.930297  0.425512  0.980648    0.5
#  1   32152  5798  0.152780  0.923313  0.321864  0.980648    1.0
#  2    1653  1085  0.396275  2.215263  0.213572  0.980648    1.5
#  3     444   156  0.260000  1.590306  0.019700  0.980648    inf
#
#     is_special_values
#  0              False
#  1              False
#  2              False
#  3              False  ,
#  'age':   variable          bin  count  count_distr   good   bad   badprob       woe  \
#  0      age  [-inf,18.0)      1     0.000007      1     0  0.000000  2.530825
#  1      age  [18.0,26.0)   3027     0.020180   2689   338  0.111662  0.562306
#  2      age  [26.0,35.0)  16212     0.108080  14400  1812  0.111769  0.563388
#  3      age  [35.0,45.0)  28563     0.190420  25978  2585  0.090502  0.328661
#  4      age  [45.0,65.0)  71004     0.473360  66495  4509  0.063503 -0.054866
#  5      age   [65.0,inf)  31193     0.207953  30411   782  0.025070 -1.024520
#
#       bin_iv  total_iv breaks  is_special_values
#  0  0.000209  0.220027   18.0              False
#  1  0.008153  0.220027   26.0              False
#  2  0.043853  0.220027   35.0              False
#  3  0.023734  0.220027   45.0              False
#  4  0.001392  0.220027   65.0              False
#  5  0.142686  0.220027    inf              False  ,
#  'NumberOfOpenCreditLinesAndLoans':                           variable          bin   count  count_distr    good  \
#  0  NumberOfOpenCreditLinesAndLoans  [-inf,11.6)  115311     0.768740  107573
#  1  NumberOfOpenCreditLinesAndLoans  [11.6,17.4)   26233     0.174887   24537
#  2  NumberOfOpenCreditLinesAndLoans   [17.4,inf)    8456     0.056373    7864
#
#      bad   badprob       woe    bin_iv  total_iv breaks  is_special_values
#  0  7738  0.067105  0.004249  0.000014  0.000375   11.6              False
#  1  1696  0.064651 -0.035635  0.000219  0.000375   17.4              False
#  2   592  0.070009  0.049731  0.000142  0.000375    inf              False  ,
#  'NumberRealEstateLoansOrLines':                        variable         bin  count  count_distr   good   bad  \
#  0  NumberRealEstateLoansOrLines  [-inf,0.5)  56188     0.374587  51516  4672
#  1  NumberRealEstateLoansOrLines   [0.5,3.0)  83860     0.559067  79347  4513
#  2  NumberRealEstateLoansOrLines   [3.0,inf)   9952     0.066347   9111   841
#
#      badprob       woe    bin_iv  total_iv breaks  is_special_values
#  0  0.083149  0.235970  0.023113  0.054798    0.5              False
#  1  0.053816 -0.230594  0.026919  0.054798    3.0              False
#  2  0.084506  0.253629  0.004766  0.054798    inf              False  ,
#  'NumberOfTime60-89DaysPastDueNotWorse':                                variable         bin   count  count_distr  \
#  0  NumberOfTime60-89DaysPastDueNotWorse  [-inf,1.0)  142396     0.949307
#  1  NumberOfTime60-89DaysPastDueNotWorse   [1.0,2.0)    5731     0.038207
#  2  NumberOfTime60-89DaysPastDueNotWorse   [2.0,inf)    1873     0.012487
#
#       good   bad   badprob       woe    bin_iv  total_iv breaks  \
#  0  135140  7256  0.050956 -0.288208  0.069673  0.599026    1.0
#  1    3954  1777  0.310068  1.836474  0.273618  0.599026    2.0
#  2     880   993  0.530166  2.757084  0.255735  0.599026    inf
#
#     is_special_values
#  0              False
#  1              False
#  2              False  ,
#  'NumberOfTimes90DaysLate':                   variable         bin   count  count_distr    good   bad  \
#  0  NumberOfTimes90DaysLate  [-inf,1.0)  141662     0.944413  135108  6554
#  1  NumberOfTimes90DaysLate   [1.0,1.5)    5243     0.034953    3478  1765
#  2  NumberOfTimes90DaysLate   [1.5,5.0)    2513     0.016753    1157  1356
#  3  NumberOfTimes90DaysLate  [5.0,10.0)     289     0.001927      98   191
#  4  NumberOfTimes90DaysLate  [10.0,inf)     293     0.001953     133   160
#
#      badprob       woe    bin_iv  total_iv breaks  is_special_values
#  0  0.046265 -0.389724  0.121413  0.875324    1.0              False
#  1  0.336639  1.957968  0.296035  0.875324    1.5              False
#  2  0.539594  2.794984  0.354914  0.875324    5.0              False
#  3  0.660900  3.303581  0.060622  0.875324   10.0              False
#  4  0.546075  2.821100  0.042340  0.875324    inf              False  ,
#  'MonthlyIncome':         variable               bin  count  count_distr   good   bad   badprob  \
#  0  MonthlyIncome           missing  29731     0.198207  28062  1669  0.056137
#  1  MonthlyIncome     [-inf,5000.0)  53102     0.354013  48452  4650  0.087567
#  2  MonthlyIncome  [5000.0,10000.0)  47382     0.315880  44531  2851  0.060171
#  3  MonthlyIncome     [10000.0,inf)  19785     0.131900  18929   856  0.043265
#
#          woe    bin_iv  total_iv   breaks  is_special_values
#  0 -0.185917  0.006324  0.067462  missing               True
#  1  0.292569  0.034419  0.067462   5000.0              False
#  2 -0.112241  0.003791  0.067462  10000.0              False
#  3 -0.459905  0.022928  0.067462      inf              False  ,
#  'NumberOfDependents':              variable         bin   count  count_distr    good   bad  \
#  0  NumberOfDependents     missing    3924     0.026160    3745   179
#  1  NumberOfDependents  [-inf,2.0)  113218     0.754787  106188  7030
#  2  NumberOfDependents  [2.0,20.0)   32857     0.219047   30040  2817
#  3  NumberOfDependents  [20.0,inf)       1     0.000007       1     0
#
#      badprob       woe    bin_iv  total_iv   breaks  is_special_values
#  0  0.045617 -0.404606  0.003602  0.026211  missing               True
#  1  0.062093 -0.078839  0.004534  0.026211      2.0              False
#  2  0.085735  0.269328  0.017865  0.026211     20.0              False
#  3  0.000000  2.530825  0.000209  0.026211      inf              False  ,
#  'Unnamed: 0':      variable                  bin  count  count_distr   good   bad   badprob  \
#  0  Unnamed: 0       [-inf,20000.0)  19999     0.133327  18715  1284  0.064203
#  1  Unnamed: 0    [20000.0,30000.0)  10000     0.066667   9343   657  0.065700
#  2  Unnamed: 0    [30000.0,45000.0)  15000     0.100000  13931  1069  0.071267
#  3  Unnamed: 0    [45000.0,70000.0)  25000     0.166667  23332  1668  0.066720
#  4  Unnamed: 0    [70000.0,95000.0)  25000     0.166667  23401  1599  0.063960
#  5  Unnamed: 0   [95000.0,105000.0)  10000     0.066667   9271   729  0.072900
#  6  Unnamed: 0  [105000.0,140000.0)  35000     0.233333  32702  2298  0.065657
#  7  Unnamed: 0       [140000.0,inf)  10001     0.066673   9279   722  0.072193
#
#          woe        bin_iv  total_iv    breaks  is_special_values
#  0 -0.043070  2.427597e-04   0.00228   20000.0              False
#  1 -0.018424  2.244903e-05   0.00228   30000.0              False
#  2  0.068882  4.888664e-04   0.00228   45000.0              False
#  3 -0.001926  6.174309e-07   0.00228   70000.0              False
#  4 -0.047125  3.626630e-04   0.00228   95000.0              False
#  5  0.093302  6.043389e-04   0.00228  105000.0              False
#  6 -0.019122  8.461587e-05   0.00228  140000.0              False
#  7  0.082791  4.737208e-04   0.00228       inf              False  }

# %%
# create scorecard
card = sc.scorecard(bins_adj, lr, xcolumns, points0=1025, odds0=1/9, pdo=41, basepoints_eq0=False, digits=0)

# %%
scorecard = {}

for key, values in card.items():
    values.fillna('missing', inplace=True)
    points_list = []
    for row in values.iterrows():
        if row[1]['bin'] == 'missing':
            points_list.append(0)
        else:
            top_value = float(row[1]['bin'][1:-1].split(',')[1] )
            if top_value == np.inf:
                points_list.append(1_000_000_000)
            else:
                points_list.append(top_value)
        points_list.append(row[1]['points'])
    scorecard[key] = points_list

# %%
for key, values in scorecard.items():
    print(key)
    print(values)
    print("===")
# Out:
# basepoints
# [0, 741.0]
# ===
# RevolvingUtilizationOfUnsecuredLines
# [0.5, 38.0, 1.0, -38.0, 1.5, -90.0, 1000000000, -65.0]
# ===
# age
# [18.0, -69.0, 26.0, -15.0, 35.0, -15.0, 45.0, -9.0, 65.0, 2.0, 1000000000, 28.0]
# ===
# NumberOfTime30-59DaysPastDueNotWorse
# [1.0, 16.0, 2.0, -27.0, 1000000000, -57.0]
# ===
# DebtRatio
# [0.3125, 7.0, 0.625, -3.0, 2.5, -29.0, 1000000000, 10.0]
# ===
# MonthlyIncome
# [0, 2.0, 5000.0, -3.0, 10000.0, 1.0, 1000000000, 5.0]
# ===
# NumberOfTimes90DaysLate
# [1.0, 12.0, 1.5, -59.0, 5.0, -84.0, 10.0, -100.0, 1000000000, -85.0]
# ===
# NumberRealEstateLoansOrLines
# [0.5, -10.0, 3.0, 10.0, 1000000000, -11.0]
# ===
# NumberOfTime60-89DaysPastDueNotWorse
# [1.0, 9.0, 2.0, -54.0, 1000000000, -82.0]
# ===
# NumberOfDependents
# [0, 11.0, 2.0, 2.0, 20.0, -7.0, 1000000000, -66.0]
# ===

# %%
scorecard
# Out:
# {'basepoints': [0, 741.0],
#  'RevolvingUtilizationOfUnsecuredLines': [0.5,
#   38.0,
#   1.0,
#   -38.0,
#   1.5,
#   -90.0,
#   1000000000,
#   -65.0],
#  'age': [18.0,
#   -69.0,
#   26.0,
#   -15.0,
#   35.0,
#   -15.0,
#   45.0,
#   -9.0,
#   65.0,
#   2.0,
#   1000000000,
#   28.0],
#  'NumberOfTime30-59DaysPastDueNotWorse': [1.0,
#   16.0,
#   2.0,
#   -27.0,
#   1000000000,
#   -57.0],
#  'DebtRatio': [0.3125, 7.0, 0.625, -3.0, 2.5, -29.0, 1000000000, 10.0],
#  'MonthlyIncome': [0, 2.0, 5000.0, -3.0, 10000.0, 1.0, 1000000000, 5.0],
#  'NumberOfTimes90DaysLate': [1.0,
#   12.0,
#   1.5,
#   -59.0,
#   5.0,
#   -84.0,
#   10.0,
#   -100.0,
#   1000000000,
#   -85.0],
#  'NumberRealEstateLoansOrLines': [0.5, -10.0, 3.0, 10.0, 1000000000, -11.0],
#  'NumberOfTime60-89DaysPastDueNotWorse': [1.0,
#   9.0,
#   2.0,
#   -54.0,
#   1000000000,
#   -82.0],
#  'NumberOfDependents': [0, 11.0, 2.0, 2.0, 20.0, -7.0, 1000000000, -66.0]}

# %%
{"":"DOB",
"":"NumberOfDependents",
"":"MonthlyIncome",
"":"MonthlyExpenses",
"":"Accounts",
"":"RevolvingUtilization",
"":"RealEstateLoans",
"":"ThirtyFiftyNinePastDue",
"":"SixtyEightyNinePastDue",
"":"NinetyDaysLate",}
# Out:
# {'': 'NinetyDaysLate'}

# %% [markdown]
# lowest values = -167
# highest_value = 624

# %%
# credit score
train_score = sc.scorecard_ply(train, card, print_step=0)
# Out:
# /Users/CWK/anaconda3/envs/minimal-ds/lib/python3.11/site-packages/scorecardpy/scorecard.py:353: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat_score.loc[:,'score'] = card_basepoints + dat_score.sum(axis=1)

# %%
train_score.min()
# Out:
# score    364.0
# dtype: float64

# %%
train_score.max()
# Out:
# score    877.0
# dtype: float64
