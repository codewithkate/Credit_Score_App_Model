# %%
# Load Imports and Libraries
import pandas as pd

# %%
# Load in train and test data
train = pd.read_csv("../../data/GiveMeSomeCredit/cs-training.csv")
test = pd.read_csv("../../data/GiveMeSomeCredit/cs-test.csv")

# %% [markdown]
# ## Training Data

# %%
# Get Data Types and null values
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Unnamed: 0                            150000 non-null  int64
#  1   SeriousDlqin2yrs                      150000 non-null  int64
#  2   RevolvingUtilizationOfUnsecuredLines  150000 non-null  float64
#  3   age                                   150000 non-null  int64
#  4   NumberOfTime30-59DaysPastDueNotWorse  150000 non-null  int64
#  5   DebtRatio                             150000 non-null  float64
#  6   MonthlyIncome                         120269 non-null  float64
#  7   NumberOfOpenCreditLinesAndLoans       150000 non-null  int64
#  8   NumberOfTimes90DaysLate               150000 non-null  int64
#  9   NumberRealEstateLoansOrLines          150000 non-null  int64
# ...

# %% [markdown]
# **Observations**
# 1. about 30k null vals for Monthly Income
# 1. about 6k null vals for # of deps
# 1. All numeric values
#
# **Solutions**
# 1. impute 'MonthlyIncome'
# 1. impute 'NumberOfDependents'
# 1. drop 'Unnamed: 0'

# %%
train.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# Preview Data
train.head()
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                 1                              0.766127   45
# 1                 0                              0.957151   40
# 2                 0                              0.658180   38
# 3                 0                              0.233810   30
# 4                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                               13                        0
# 1                                4                        0
# ...

# %%
train.iloc[: 1:].describe()
# Out:
#        RevolvingUtilizationOfUnsecuredLines            age  \
# count                         150000.000000  150000.000000
# mean                               6.048438      52.295207
# std                              249.755371      14.771866
# min                                0.000000       0.000000
# 25%                                0.029867      41.000000
# 50%                                0.154181      52.000000
# 75%                                0.559046      63.000000
# max                            50708.000000     109.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         150000.000000  150000.000000   1.202690e+05
# mean                               0.421033     353.005076   6.670221e+03
# std                                4.192781    2037.818523   1.438467e+04
# min                                0.000000       0.000000   0.000000e+00
# ...

# %% [markdown]
# **Observations**
# 1. 'RevolvingUtilizationOfUnsecuredLines' should be between 0 and 1
#
# **Solution**
# 1. use top-coding method?

# %%
# Refine Target Column with 0 and 1 values
train['SeriousDlqin2yrs'].value_counts()
# Out:
# 0    139974
# 1     10026
# Name: SeriousDlqin2yrs, dtype: int64

# %% [markdown]
# **Observations**
# 1. True binary target column
# 1. imbalanced with more bad borrowers
#
# **Solutions**
# 1. Research how to handle imbalanced data

# %% [markdown]
# ## Test Data

# %%
# Get Data Types and null values

# %%
# Preview Data

# %%
# Refine Target Column with 0 and 1 values

# %% [markdown]
# ## Sample Model Output

# %%
# Load Sample Entry data
pd.read_csv("../../data/GiveMeSomeCredit/sampleEntry.csv")
# Out:
#             Id  Probability
# 0            1     0.080807
# 1            2     0.040719
# 2            3     0.011968
# 3            4     0.067640
# 4            5     0.108264
# ...        ...          ...
# 101498  101499     0.045363
# 101499  101500     0.343775
# 101500  101501     0.006970
# 101501  101502     0.121994
# 101502  101503     0.044248
#
# [101503 rows x 2 columns]

# %%
def predict_score(array):
    return dict(id, score)
